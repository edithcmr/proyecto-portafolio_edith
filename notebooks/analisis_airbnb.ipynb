# %%
import pandas as pd
import numpy as np

# %%
#Leyendo la base de datos
base=pd.read_csv('C:/Users/edihc/Documents/GitHub/proyecto-portafolio_edith/datos/airbnb.csv')

# %%
base
# Out:
#              id                            listing_url       scrape_id  \
# 0          6369      https://www.airbnb.com/rooms/6369  20210413152844
# 1         21853     https://www.airbnb.com/rooms/21853  20210413152844
# 2         23001     https://www.airbnb.com/rooms/23001  20210413152844
# 3         24805     https://www.airbnb.com/rooms/24805  20210413152844
# 4         26825     https://www.airbnb.com/rooms/26825  20210413152844
# ...         ...                                    ...             ...
# 19613  49185822  https://www.airbnb.com/rooms/49185822  20210413152844
# 19614  49186179  https://www.airbnb.com/rooms/49186179  20210413152844
# 19615  49187258  https://www.airbnb.com/rooms/49187258  20210413152844
# 19616  49187471  https://www.airbnb.com/rooms/49187471  20210413152844
# 19617  49187791  https://www.airbnb.com/rooms/49187791  20210413152844
#
#       last_scraped                                         name  \
# ...

# %%
base.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   6369   https://www.airbnb.com/rooms/6369  20210413152844   2021-04-15
# 1  21853  https://www.airbnb.com/rooms/21853  20210413152844   2021-04-16
# 2  23001  https://www.airbnb.com/rooms/23001  20210413152844   2021-04-16
# 3  24805  https://www.airbnb.com/rooms/24805  20210413152844   2021-04-15
# 4  26825  https://www.airbnb.com/rooms/26825  20210413152844   2021-04-15
#
#                                        name  \
# 0  Rooftop terrace room ,  ensuite bathroom
# 1                      Bright and airy room
# 2         Apartmento Arganzuela- Madrid Rio
# 3                    Gran Via Studio Madrid
# 4        Single Room whith private Bathroom
#
#                                          description  \
# 0  Excellent connection with the AIRPORT and EXHI...
# 1  We have a quiet and sunny room with a good vie...
# 2  Apartamento de tres dormitorios dobles, gran s...
# ...

# %%
# seleccionar barrios y tipos de alojamiento
alojamiento=base[['room_type','neighbourhood_cleansed']]
alojamiento
# Out:
#              room_type neighbourhood_cleansed
# 0         Private room         Hispanoamérica
# 1         Private room               Cármenes
# 2      Entire home/apt                Legazpi
# 3      Entire home/apt            Universidad
# 4         Private room                Legazpi
# ...                ...                    ...
# 19613     Private room            Embajadores
# 19614     Private room             Gaztambide
# 19615     Private room               Arapiles
# 19616     Private room             Guindalera
# 19617     Private room               Arapiles
#
# [19618 rows x 2 columns]

# %%
#¿cuantos tipos de alojamiento existen en Madrid?
alojamiento = alojamiento.groupby('room_type',).count().reset_index()
alojamiento
import seaborn as sb
alojamiento = alojamiento.rename(columns={'neighbourhood_cleansed':'n'})
alojamiento
# Out:
#          room_type      n
# 0  Entire home/apt  11314
# 1       Hotel room    166
# 2     Private room   7809
# 3      Shared room    329

# %%
# ordenar los alojamientos de mayor a menor y graficar
alojamiento_sort=alojamiento.sort_values('n', ascending=False)

# %%
#gráfico de barras para tipo de alojamiento
import matplotlib.pyplot as plt
plt.bar(alojamiento_sort['room_type'], alojamiento_sort['n'],
       color=['g', 'y', 'b', 'r'])

plt.show()

# %%
#cuantos alojamientos hay por barrio
barrio= base[['neighbourhood_cleansed', 'room_type','beds', 'price','accommodates']]

# %%
barrio
# Out:
#       neighbourhood_cleansed        room_type  beds   price  accommodates
# 0             Hispanoamérica     Private room   1.0  $60.00             2
# 1                   Cármenes     Private room   1.0  $31.00             1
# 2                    Legazpi  Entire home/apt   5.0  $50.00             6
# 3                Universidad  Entire home/apt   1.0  $92.00             3
# 4                    Legazpi     Private room   1.0  $26.00             1
# ...                      ...              ...   ...     ...           ...
# 19613            Embajadores     Private room   1.0  $23.00             1
# 19614             Gaztambide     Private room   1.0  $21.00             1
# 19615               Arapiles     Private room   1.0  $22.00             1
# 19616             Guindalera     Private room   1.0  $19.00             1
# 19617               Arapiles     Private room   NaN  $20.00             1
#
# [19618 rows x 5 columns]

# %%
#agrupar por barrios
total_barrios=barrio.groupby(['neighbourhood_cleansed','room_type']).sum()

# %%
total_barrios
# Out:
#                                          beds  accommodates
# neighbourhood_cleansed room_type
# Abrantes               Entire home/apt   29.0            44
#                        Private room      35.0            48
#                        Shared room        3.0             3
# Acacias                Entire home/apt  168.0           280
#                        Private room     109.0           158
# ...                                       ...           ...
# Vinateros              Shared room        1.0             2
# Vista Alegre           Entire home/apt   89.0           169
#                        Private room      86.0           141
# Zofío                  Entire home/apt   22.0            42
#                        Private room      21.0            31
#
# [352 rows x 2 columns]

# %%
total_barrios=total_barrios.sort_values('beds', ascending=False)

# %%
total_barrios
# Out:
#                                           beds  accommodates
# neighbourhood_cleansed room_type
# Embajadores            Entire home/apt  3783.0          6555
# Universidad            Entire home/apt  2664.0          4735
# Palacio                Entire home/apt  2549.0          4349
# Sol                    Entire home/apt  2064.0          3578
# Cortes                 Entire home/apt  1662.0          2849
# ...                                        ...           ...
# Entrevías              Shared room         0.0             1
# Media Legua            Hotel room          0.0            12
# Imperial               Hotel room          0.0            12
# Atocha                 Shared room         0.0             1
# Palomeras Bajas        Shared room         0.0             1
#
# [352 rows x 2 columns]

# %%
#Capacidad total de los alojamientos
capacidad = barrio.groupby('room_type').sum()
capacidad= capacidad['beds'].reset_index()

# %%
capacidad
# Out:
#          room_type     beds
# 0  Entire home/apt  26970.0
# 1       Hotel room    217.0
# 2     Private room   9260.0
# 3      Shared room   1129.0

# %%
plt.pie(capacidad['beds'],
        labels=capacidad['room_type'],
        colors=['b','y','g','r'],
        shadow=True,
        autopct='%1.0f%%',
        textprops=dict(color="w", weight="bold", size=15)
       )
plt.show()

# %%
plt.pie(capacidad['beds'],
        labels=capacidad['room_type'])
plt.show()

# %%
#cuáles son los barrios que tienen mas alojamientos completos?
barrio_completa =  barrio.groupby(barrio[barrio['room_type'] == 'Entire home/apt']['neighbourhood_cleansed']).sum()
barrio_completa= barrio_completa['beds'].reset_index()
barrio_completa=iento.sort_values('n', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-479752e9ff19> in <module>
#       2 barrio_completa =  barrio.groupby(barrio[barrio['room_type'] == 'Entire home/apt']['neighbourhood_cleansed']).sum()
#       3 barrio_completa= barrio_completa['beds'].reset_index()
# ----> 4 barrio_completa = barrio_completa.sort['beds']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'
